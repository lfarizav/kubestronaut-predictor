# %% [markdown]
# # 🏠 House Data Exploration
# This notebook performs initial data exploration on the `house_data.csv` dataset.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('../data/raw/kubestronaut-prediction-data.csv')

# ℹ️ Display basic information about the dataset
print(f"📐 Dataset shape (rows, columns): {df.shape}")
print("\n📊 Dataset Info:")
print(df.info())
# Out:
# 📐 Dataset shape (rows, columns): (1000, 6)
#
# 📊 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   theory_hours          1000 non-null   int64
#  1   lab_hours             1000 non-null   int64
#  2   k8s_experience_level  1000 non-null   int64
#  3   response_speed        1000 non-null   float64
#  4   exam_attempts         1000 non-null   int64
#  5   final_result          1000 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 47.0 KB
# None

# %%
# ❓ Checking for missing values to identify data quality issues
print("\n🔍 Missing values per column:")
print(df.isnull().sum())
# Out:
# 🔍 Missing values per column:
# theory_hours            0
# lab_hours               0
# k8s_experience_level    0
# response_speed          0
# exam_attempts           0
# final_result            0
# dtype: int64

# %%
# 📈 Descriptive statistics like mean, std deviation, min, max, etc.
print("\n📋 Statistical Summary:")
print(df.describe())
# Out:
# 📋 Statistical Summary:
#        theory_hours    lab_hours  k8s_experience_level  response_speed  \
# count   1000.000000  1000.000000           1000.000000     1000.000000
# mean     101.327000   149.131000              4.899000       34.736060
# std       57.934899    89.198757              3.046651       14.370752
# min        0.000000     0.000000              0.000000       10.000000
# 25%       51.000000    74.000000              2.000000       22.995000
# 50%      103.000000   149.500000              5.000000       34.660000
# 75%      150.000000   225.000000              8.000000       46.845000
# max      200.000000   300.000000             10.000000       59.890000
#
#        exam_attempts  final_result
# count    1000.000000   1000.000000
# mean        3.066000      0.050000
# std         1.406279      0.218054
# min         1.000000      0.000000
# 25%         2.000000      0.000000
# 50%         3.000000      0.000000
# 75%         4.000000      0.000000
# ...

# %%
# 💰 Visualizing the distribution of house prices
plt.figure(figsize=(10, 6))
sns.histplot(df['theory_hours'], kde=True)
plt.title('Kubestronaut-theory-hours Distribution')
plt.xlabel('theory_hours')
plt.ylabel('Frequency')
plt.show()

print("📊 Plotted kubestronaut theory hours distribution.")
# Out:
# 📊 Plotted kubestronaut theory hours distribution.

# %%
# 🔗 Checking how features are correlated with each other
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

print("📈 Displayed feature correlation heatmap.")
# Out:
# 📈 Displayed feature correlation heatmap.

# %%
# 📏 Scatter plot to observe relationship between sqft and price
plt.figure(figsize=(10, 6))
sns.scatterplot(x='lab_hours', y='theory_hours', data=df)
plt.title('Theory hours vs Laboratory hours')
plt.xlabel('Laboratory hours')
plt.ylabel('Theory hours')
plt.show()

print("📐 Analyzed relation between square footage and price.")
# Out:
# 📐 Analyzed relation between square footage and price.

# %%
# 📍 Bar chart to see experience years in kubernetes
plt.figure(figsize=(10, 6))
sns.countplot(x='k8s_experience_level', data=df)
plt.title('People with experience in Kubernetes')
plt.xlabel('Years of Kubernetes Experience')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

print("📍 Visualized distribution of people with years of kubernetes experience.")
# Out:
# 📍 Visualized distribution of people with years of kubernetes experience.

# %%
# 🛏️ Bar chart showing the exam_attempts with Kubernetes experience level
plt.figure(figsize=(10, 7))
sns.barplot(x='exam_attempts', y='k8s_experience_level', data=df)
plt.title('Exam attempts with Kubernetes experience level')
plt.xlabel('exam_attempts')
plt.ylabel('Kubernetes Experience Level')
plt.show()

print("Compared Exam attempts with Kubernetes experience level.")
# Out:
# Compared Exam attempts with Kubernetes experience level.

# %%
# Next Step 
# Feature Engineering
# Create new features or modify existing ones
