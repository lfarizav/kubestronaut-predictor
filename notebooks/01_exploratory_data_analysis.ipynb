# %% [markdown]
# # 🏠 House Data Exploration
# This notebook performs initial data exploration on the `house_data.csv` dataset.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('../data/raw/kubestronaut_predictor_data.csv')

# ℹ️ Display basic information about the dataset
print(f"📐 Dataset shape (rows, columns): {df.shape}")
print("\n📊 Dataset Info:")
print(df.info())
# Out:
# 📐 Dataset shape (rows, columns): (77, 8)
#
# 📊 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   final_result           77 non-null     float64
#  1   theory_hours           77 non-null     int64
#  2   lab_hours              77 non-null     int64
#  3   number_full_exam_done  77 non-null     float64
#  4   cncf_try_numbers       77 non-null     float64
#  5   location               77 non-null     object
#  6   born_year              77 non-null     int64
#  7   selfassessment         77 non-null     object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 4.9+ KB
# None

# %%
# ❓ Checking for missing values to identify data quality issues
print("\n🔍 Missing values per column:")
print(df.isnull().sum())
# Out:
# 🔍 Missing values per column:
# final_result             0
# theory_hours             0
# lab_hours                0
# number_full_exam_done    0
# cncf_try_numbers         0
# location                 0
# born_year                0
# selfassessment           0
# dtype: int64

# %%
# 📈 Descriptive statistics like mean, std deviation, min, max, etc.
print("\n📋 Statistical Summary:")
print(df.describe())
# Out:
# 📋 Statistical Summary:
#        final_result  theory_hours    lab_hours  number_full_exam_done  \
# count     77.000000     77.000000    77.000000              77.000000
# mean       0.303930   1106.961039  1205.818182               2.694805
# std        0.264887    552.601323   628.678098               0.688992
# min        0.000000    350.000000     0.000000               2.000000
# 25%        0.118881    700.000000   800.000000               2.000000
# 50%        0.245754    980.000000  1000.000000               3.000000
# 75%        0.370629   1450.000000  1600.000000               3.000000
# max        1.000000   2680.000000  3200.000000               4.000000
#
#        cncf_try_numbers    born_year
# count         77.000000    77.000000
# mean           2.019481  1979.025974
# std            0.640937    17.427273
# min            1.000000  1947.000000
# 25%            1.500000  1965.000000
# 50%            2.000000  1981.000000
# 75%            2.500000  1992.000000
# ...

# %%
# 💰 Visualizing the distribution of kubestronaut final result
plt.figure(figsize=(10, 6))
sns.histplot(df['final_result'], kde=True)
plt.title('Kubestronaut final result Distribution')
plt.xlabel('final_result')
plt.ylabel('Frequency')
plt.show()

print("📊 Plotted Kubestronaut predictor distribution.")
# Out:
# 📊 Plotted Kubestronaut predictor distribution.

# %%
# 🔗 Checking how features are correlated with each other
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

print("📈 Displayed feature correlation heatmap.")
# Out:
# /tmp/ipykernel_50930/1940117329.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
# 📈 Displayed feature correlation heatmap.

# %%
# 📏 Scatter plot to observe relationship theory hours and final result
plt.figure(figsize=(10, 6))
sns.scatterplot(x='theory_hours', y='final_result', data=df)
plt.title('Final result vs Theory hours')
plt.xlabel('Theory_hours')
plt.ylabel('Final_result')
plt.show()

print("📐 Analyzed relation between square footage and price.")
# Out:
# 📐 Analyzed relation between square footage and price.

# %%
# 📏 Scatter plot to observe relationship between laboratory hours and final result
plt.figure(figsize=(10, 6))
sns.scatterplot(x='lab_hours', y='final_result', data=df)
plt.title('Final result vs Laboratory hours')
plt.xlabel('Laboratory hours')
plt.ylabel('Final result')
plt.show()

print("📐 Analyzed relation between square footage and price.")
# Out:
# 📐 Analyzed relation between square footage and price.

# %%
# 📍 Bar chart to see how many people exist in each location
plt.figure(figsize=(10, 6))
sns.countplot(x='location', data=df)
plt.title('People by Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

print("📍 Visualized distribution of people by location.")
# Out:
# 📍 Visualized distribution of people by location.

# %%
# 🛏️ Bar chart showing how average final result varies by number of full exams done
plt.figure(figsize=(10, 6))
sns.barplot(x='number_full_exam_done', y='final_result', data=df)
plt.title('Average final_result by number_full_exam_done')
plt.xlabel('number_full_exam_done')
plt.ylabel('Average final_result')
plt.show()

print("🛏️ Compared average result varies by number of full exams done.")
# Out:
# 🛏️ Compared average result varies by number of full exams done.

# %%
# Next Step 
# Feature Engineering
# Create new features or modify existing ones
